# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle

# %%
df = pd.read_csv("Automobile_insurance_fraud.csv")
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %% [markdown]
# # EDA

# %%
pol_state = df['policy_state'].value_counts()

plt.figure(figsize=(5, 5))
sns.barplot(pol_state.index, pol_state.values, palette='bright')
plt.title('policy state')
plt.xlabel('policy state')
plt.style.use('bmh')
plt.ylabel('Count')
plt.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# All the three policy state has almost same count.

# %%
df = df.drop(["_c39"], axis = 1)

# %%
insured_sex = df['insured_sex'].value_counts()

plt.figure(figsize=(5, 5))
sns.barplot(insured_sex.index, insured_sex.values, palette='bright')
plt.title('insured sex')
plt.xlabel('insured sex')
plt.style.use('bmh')
plt.ylabel('Count')
plt.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# No much difference between the count of male and female.

# %%
insured_education_level = df['insured_education_level'].value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(insured_education_level.values, insured_education_level.index, palette='bright')
plt.title('insured education level')
plt.xlabel('Count')
plt.ylabel('insured education level')
plt.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# The count for each educational qualification are comparable.

# %%
insured_occupation = df['insured_occupation'].value_counts()

plt.figure(figsize=(7, 7))
sns.barplot(insured_occupation.values, insured_occupation.index, palette='bright')
plt.title('insured occupation')
plt.style.use('bmh')
plt.xlabel('Count')
plt.ylabel('insured occupation')
plt.tick_params(labelsize=13)
plt.show()

# %%
insured_hobbies = df['insured_hobbies'].value_counts()

plt.figure(figsize=(7, 7))
plt.style.use('bmh')
sns.barplot(insured_hobbies.values, insured_hobbies.index, palette='bright')
plt.title('insured hobbies')
plt.xlabel('Count')
plt.ylabel('insured hobbies')
plt.tick_params(labelsize=13)
plt.show()

# %%
insured_relationship = df['insured_relationship'].value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(insured_relationship.values, insured_relationship.index, palette='bright')
plt.title('insured relationship')
plt.xlabel('Count')
plt.ylabel('insured relationship')
plt.tick_params(labelsize=12)
plt.show()

# %%
collision_type = df['collision_type'].replace("?", "other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(collision_type.values, collision_type.index, palette='bright')
plt.title('collision type')
plt.xlabel('Count')
plt.ylabel('collision type')
plt.tick_params(labelsize=12)
plt.show()

# %%
incident_type = df['incident_type'].replace("?", "other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(incident_type.values, incident_type.index, palette='bright')
plt.title('incident type')
plt.xlabel('Count')
plt.ylabel('incident type')
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# The incident with the parked car and the vehicle theft are much less than the incidents of collisions.

# %%
incident_severity = df['incident_severity'].replace("?", "other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(incident_severity.values, incident_severity.index, palette='bright')
plt.title('incident severity')
plt.xlabel('Count')
plt.ylabel('incident severity')
plt.tick_params(labelsize=12)
plt.show()

# %%
authorities_contacted = df['authorities_contacted'].replace("?", "other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(authorities_contacted.values, authorities_contacted.index, palette='bright')
plt.title('authorities contacted')
plt.xlabel('Count')
plt.ylabel('authorities contacted')
plt.tick_params(labelsize=12)
plt.show()

# %%
incident_state = df['incident_state'].replace("?", "other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(incident_state.values, incident_state.index, palette='bright')
plt.title('incident state')
plt.xlabel('Count')
plt.ylabel('incident state')
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# The number of incidents reported from the states PA and OH is much smaller than the other states.

# %%
incident_hour_of_the_day = df['incident_hour_of_the_day'].value_counts()

plt.figure(figsize=(10, 8))
plt.style.use('bmh')
sns.barplot(incident_hour_of_the_day.index, incident_hour_of_the_day.values, palette='bright')
plt.title('incident hour of the day')
plt.ylabel('Count')
plt.xlabel('incident hour of the day')
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# The incidents are reported throughout the whole day almost uniformely.

# %%
property_damage = df['property_damage'].replace("?","other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(property_damage.index, property_damage.values, palette='bright')
plt.title('property damage')
plt.ylabel('Count')
plt.xlabel('property damage')
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# in almost 36% of the cases are those in which the damage of the property was not known.

# %%
police_report_available = df['police_report_available'].replace("?","other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(police_report_available.index, police_report_available.values, palette='bright')
plt.title('police report available')
plt.ylabel('Count')
plt.xlabel('police report available')
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# in almost 34% of the case police report is not known.

# %%
auto_make = df['auto_make'].replace("?","other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(auto_make.values, auto_make.index, palette='bright')
plt.title('auto make')
plt.xlabel('Count')
plt.ylabel('auto make')
plt.tick_params(labelsize=12)
plt.show()

# %%
auto_model = df['auto_model'].replace("?","other").value_counts()

plt.figure(figsize=(7, 12))
sns.barplot(auto_model.values, auto_model.index, palette='bright')
plt.style.use('bmh')
plt.title('auto model')
plt.xlabel('Count')
plt.ylabel('auto model')
plt.tick_params(labelsize=12)
plt.show()

# %%
auto_year = df['auto_year'].replace("?","other").value_counts()

plt.figure(figsize=(15, 5))
plt.style.use('bmh')
sns.barplot(auto_year.index, auto_year.values,  palette='bright')
plt.title('auto year')
plt.ylabel('Count')
plt.xlabel('auto year')
plt.tick_params(labelsize=12)
plt.show()

# %%
fraud_reported = df['fraud_reported'].replace("?","other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(fraud_reported.index, fraud_reported.values,  palette='bright')
plt.title('fraud reported')
plt.ylabel('Count')
plt.xlabel('fraud reported')
plt.tick_params(labelsize=12)
plt.show()

# %% [markdown]
# 75% of the incidents are not reprted.

# %% [markdown]
# #### filtering the numerical variables

# %%
feat = list(df.columns)
cat_feat = []
num_feat = []
for feat in feat:
    if feat == "fraud_reported":
        pass
    elif df[feat].dtypes == "object":
        cat_feat.append(feat)
    else:
        num_feat.append(feat)

# %%
num_feat
# Out:
# ['months_as_customer',
#  'age',
#  'policy_number',
#  'policy_deductable',
#  'policy_annual_premium',
#  'umbrella_limit',
#  'insured_zip',
#  'capital-gains',
#  'capital-loss',
#  'incident_hour_of_the_day',
#  'number_of_vehicles_involved',
#  'bodily_injuries',
#  'witnesses',
#  'total_claim_amount',
#  'injury_claim',
#  'property_claim',
#  'vehicle_claim',
#  'auto_year']

# %%
plt.figure(figsize=(7, 7))
df["months_as_customer"].hist(color='b', alpha=1, bins=25)
#plt.xlabel()
plt.ylabel('count')
plt.title('months as customer')
plt.tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["age"].hist(color='b', alpha=1, bins=25)
#plt.xlabel()
plt.ylabel('count')
plt.title('age')
plt.tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["policy_annual_premium"].hist(color='b', alpha=1, bins=25)
#plt.xlabel()
plt.ylabel('count')
plt.title('policy annual premium')
plt.tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["insured_zip"].hist(color='b', alpha=1, bins=25)
#plt.xlabel()
plt.ylabel('count')
plt.title('insured zip')
plt.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# The distribution is a bit weird. There are instances of large values around 610000 and small values around 460000. In-between values are absent.

# %%
plt.figure(figsize=(7, 7))
df["umbrella_limit"].hist(color='b', alpha=1, bins=10)
#plt.xlabel()
plt.ylabel('count')
plt.title('umbrella limit')
plt.tick_params(labelsize=10)
plt.show()

# %%
bodily_injuries = df['bodily_injuries'].replace("?","other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(bodily_injuries.index, bodily_injuries.values,  palette='bright')
plt.title('bodily injuries')
plt.ylabel('Count')
plt.xlabel('bodily injuries')
plt.tick_params(labelsize=12)
plt.show()

# %%
witnesses = df['witnesses'].replace("?","other").value_counts()

plt.figure(figsize=(5, 5))
plt.style.use('bmh')
sns.barplot(witnesses.index, witnesses.values,  palette='bright')
plt.title('witnesses')
plt.ylabel('Count')
plt.xlabel('witnesses')
plt.tick_params(labelsize=12)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["total_claim_amount"].hist(color='b', alpha=1, bins=10)
#plt.xlabel()
plt.ylabel('count')
plt.title('total claim amount')
plt.tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["injury_claim"].hist(color='b', alpha=1, bins=10)
#plt.xlabel()
plt.ylabel('count')
plt.title('injury claim')
plt.tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["property_claim"].hist(color='b', alpha=1, bins=10)
#plt.xlabel()
plt.ylabel('count')
plt.title('property claim')
plt.tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(7, 7))
df["vehicle_claim"].hist(color='b', alpha=1, bins=10)
#plt.xlabel()
plt.ylabel('count')
plt.title('vehicle claim')
plt.tick_params(labelsize=10)
plt.show()

# %% [markdown]
# ## correlation

# %%
heat_feat = ['months_as_customer','age','policy_deductable','policy_annual_premium','umbrella_limit','insured_zip',
             'capital-gains','capital-loss','incident_hour_of_the_day','total_claim_amount','injury_claim',
             'property_claim','vehicle_claim']

# %%
sns.heatmap(df[heat_feat].corr())

# %% [markdown]
# total claim, injury claim, property claim and vehicle claim are correlated and age & months as costumer also correlated featues.

# %% [markdown]
# we are dropping injury claim, property claim, vehicle claim and age.

# %%
df = df.drop(["injury_claim", "property_claim", "vehicle_claim", "age"], axis = 1)

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# bodily_injuries                0
# ...

# %% [markdown]
# ## outlier

# %%
num_feat = ['months_as_customer','policy_deductable','policy_annual_premium','umbrella_limit','insured_zip',
             'capital-gains','capital-loss','incident_hour_of_the_day','total_claim_amount']
for i in num_feat:
    plt.figure()
    sns.boxplot(x=df[i])

# %% [markdown]
# As we can see that few of the features has outlier. Umbrella limit features can be dropped because it has almost same value for most of the instance.

# %%
df1 = df # creating a copy of data
for i in num_feat:
    Q1 = df[i].quantile(0.25)
    Q3 = df[i].quantile(0.75)
    IQR = Q3 - Q1    #IQR is interquartile range. 
    filter = (df[i] >= Q1 - 1.5 * IQR) & (df[i] <= Q3 + 1.5 *IQR)
    df = df.loc[filter]
df.shape
# Out:
# (790, 35)

# %%
df1.shape
# Out:
# (1000, 35)

# %% [markdown]
# ## splitting the features and the targets

# %%
df.columns
# Out:
# Index(['months_as_customer', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'auto_make', 'auto_model', 'auto_year', 'fraud_reported'],
#       dtype='object')

# %%
num_feat = ['months_as_customer','policy_number', 'policy_deductable', 'policy_annual_premium', 'insured_zip', 
            'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries',
            'witnesses','total_claim_amount','auto_year']

# %% [markdown]
# ## label encoding

# %%
from sklearn.preprocessing import LabelEncoder

for columns in cat_feat:
    encoder = LabelEncoder()
    df[columns] = encoder.fit_transform(df[columns])

# %%
df = df.drop("umbrella_limit", axis = 1)

# %%
df = df.replace("Y", 1)
df = df.replace("N", 0)

# %% [markdown]
# ## balancing the data

# %%
df.fraud_reported.value_counts()
# Out:
# 0    605
# 1    185
# Name: fraud_reported, dtype: int64

# %%
605-185
# Out:
# 420

# %%
df1 = df[df["fraud_reported"]==1]
df2 = df[df["fraud_reported"]==0]

# %%
import secrets
ls = range(185)

for i in range(420):
    x = secrets.choice(ls)
    try:
        df1 = df1.append(df1.iloc[x])
    except:
        print (x)
df1.shape
# Out:
# (605, 34)

# %%
from sklearn.utils import shuffle
dframes = [df1, df2]
df = pd.concat(dframes)

# shuffling the data
df = shuffle(df)
df.shape
# Out:
# (1210, 34)

# %%
X = df.drop(["fraud_reported"], axis = 1)
y = df["fraud_reported"]

# %% [markdown]
# ## scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
for col in num_feat:
    scaler = MinMaxScaler()
    X[col] = scaler.fit_transform(X[col].values.reshape(-1, 1))

# %% [markdown]
# ## logistic regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state=42, solver = "sag", max_iter = 15000)
LR.fit(X_train, y_train)
y_pred_LR = LR.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

accuracy = round(accuracy_score(y_test, y_pred_LR),3)
accuracy
# Out:
# 0.793

# %%
conf_m = confusion_matrix(y_test, y_pred_LR)
print(conf_m)
# Out:
# [[93 28]
#  [22 99]]

# %% [markdown]
# ## decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier(random_state=42)
DT.fit(X_train, y_train)
y_pred_DT = DT.predict(X_test)

# %%
accuracy = round(accuracy_score(y_test, y_pred_DT),3)
accuracy
# Out:
# 0.938

# %%
conf_m = confusion_matrix(y_test, y_pred_DT)
conf_m
# Out:
# array([[111,  10],
#        [  5, 116]], dtype=int64)

# %% [markdown]
# ## random forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state=42)
RF.fit(X_train, y_train)
y_pred_RF = RF.predict(X_test)
accuracy = round(accuracy_score(y_test, y_pred_RF),3)
accuracy
# Out:
# 0.942

# %%
conf_m = confusion_matrix(y_test, y_pred_RF)
conf_m
# Out:
# array([[113,   8],
#        [  6, 115]], dtype=int64)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(X_train, y_train)
y_pred_KNN = KNN.predict(X_test)
accuracy = round(accuracy_score(y_test, y_pred_KNN),3)
accuracy
# Out:
# 0.645

# %%
conf_m = confusion_matrix(y_test, y_pred_KNN)
conf_m
# Out:
# array([[65, 56],
#        [30, 91]], dtype=int64)

# %% [markdown]
# ## Fine tuning the best model

# %%
from sklearn.model_selection import GridSearchCV
param_dict = {
    "random_state":range(1,20,3),
    "max_depth":range(4,10,2),
    "min_samples_split":range(2,10,2),
    "min_samples_leaf":range(1,5)
}
grid_RF = GridSearchCV(RF,
                      param_grid=param_dict,
                      cv = 5,
                      verbose = 1,
                      n_jobs = -1)
grid_RF.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 336 candidates, totalling 1680 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': range(4, 10, 2),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(2, 10, 2),
#                          'random_state': range(1, 20, 3)},
#              verbose=1)

# %%
y_pred_GS = grid_RF.predict(X_test)
accuracy = round(accuracy_score(y_test, y_pred_GS),3)
accuracy
# Out:
# 0.93

# %% [markdown]
# Accuracy not improved after grid search.

# %% [markdown]
# We can improve the accuracy by using ROC-AUC curve.

# %%
import numpy as np
cols = ["Thresholds",'TP', 'FP', 'TN','FN']
lst = []
for i in np.arange(0,1.1,0.1):
    y_pred = np.where(RF.predict_proba(X_test)[:,1]>i,1,0)
    tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
    lst.append([round(i,1),tp,fp,tn,fn])
confusion_result_RF = pd.DataFrame(lst, columns=cols)

# %%
def calculate_metrics(results):
    roc = pd.DataFrame(index = results['Thresholds'], columns=['recall', 'precision', 'f1', 'tpr', 'fpr'])
    
    for i in results.iterrows():
        
        t, tp, fp,tn, fn = i[1]
        
        recall = tp / (tp + fn)
        
        if tp == fp == 0:
            precision = 0
            true_positive_rate = 0
        
        else:
            precision = tp / (tp + fp)
            true_positive_rate = tp / (tp + fn)
            
        if precision == recall == 0:
            f1 = 0
        else:
            f1 = 2 * (precision * recall) / (precision + recall)
        
        
        false_positive_rate = fp / (fp + tn)
        
        roc.ix[t, 'recall'] = recall
        roc.ix[t, 'precision'] = precision
        roc.ix[t, 'f1'] = f1
        roc.ix[t, 'tpr'] = true_positive_rate
        roc.ix[t, 'fpr'] = false_positive_rate
    
    return roc

# %%
roc_RF = calculate_metrics(confusion_result_RF)
roc_RF.reset_index()
# Out:
# C:\Users\Surjeet\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\Users\Surjeet\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# C:\Users\Surjeet\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# ...

# %%
# %pylab inline
figsize(8, 7)
plt.style.use('seaborn-dark-palette')
thresholds = [str(t) for t in confusion_result_RF['Thresholds']]
plt.plot(roc_RF['fpr'], roc_RF['tpr'], 'bo-', label = 'Random Forest');
plt.plot(list(np.linspace(0, 1, num = 10)), list(np.linspace(0, 1, num = 10)), 'ro--', label = 'naive classifier');
for x, y, s in zip(roc_RF['fpr'], roc_RF['tpr'], thresholds):
    plt.text(x - 0.04,y + 0.02, s, fontdict={'size': 14});

plt.legend(prop={'size':14})
plt.xlim([0,1])
plt.ylim([0,1])
plt.ylabel('True Positive Rate', size = 16); plt.xlabel('False Positive Rate', size = 16);
plt.title('ROC Curve for insurance fraud', size = 20);
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# f1 score is maximum for the threshold value 0.6.

# %%
y_pred = np.where(RF.predict_proba(X_test)[:,1]>0.6,1,0)
pd.crosstab(y_test, y_pred)
# Out:
# col_0             0    1
# fraud_reported
# 0.0             119    2
# 1.0               6  115

# %%
y_pred = np.where(RF.predict_proba(X_test)[:,1]>0.6,1,0)
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
print("TN:",tn,"FP:",fp,"FN:",fn,"TP:",tp)
recall = round(tp/(tp+fn),2)
print("True positive rate:",recall)
print("False positive rate:",round(fp/(fp+tn),2))
precision = round(tp/(tp+fp),2)
print("Precision:",precision)
print("f-measure:",round(2*recall*precision/(recall+precision),2))
# Out:
# TN: 119 FP: 2 FN: 6 TP: 115
# True positive rate: 0.95
# False positive rate: 0.02
# Precision: 0.98
# f-measure: 0.96

# %%
accuracy = round(accuracy_score(y_test, y_pred),3)
accuracy
# Out:
# 0.967

# %% [markdown]
# The accuracy of the model is reached 97%. It is a quite good accuracy.

# %% [markdown]
# Saving the model as pkl file.

# %%
import pickle
pickle.dump(RF, open('best_model.pkl','wb'))
